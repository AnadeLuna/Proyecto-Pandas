# %% [markdown]
#    # Analise the Global Shark Attaks.

# %% [markdown]
# ### 1º: Import all the libraries that i will need use to clean the DataSet.

# %%
import numpy as np
import pandas as pd
import re

# %% [markdown]
# ### 2º: Import the DataSet from Kaggle. The Global Shark Attacks.

# %%
data = pd.read_csv("../data/attacks.csv",encoding = "ISO-8859-1")
data
data.head(10)
# Out:
#     Case Number         Date    Year        Type    Country             Area  \
# 0    2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1    2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2    2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3    2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4    2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
# 5  2018.06.03.b  03-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 6  2018.06.03.a  03-Jun-2018  2018.0  Unprovoked     BRAZIL       Pernambuco
# 7    2018.05.27  27-May-2018  2018.0  Unprovoked        USA          Florida
# 8  2018.05.26.b  26-May-2018  2018.0  Unprovoked        USA          Florida
# 9  2018.05.26.a  26-May-2018  2018.0  Unprovoked        USA          Florida
#
#                                             Location      Activity  \
# 0                        Oceanside, San Diego County      Paddling
# 1                     St. Simon Island, Glynn County      Standing
# 2                                       Habush, Oahu       Surfing
# 3                                 Arrawarra Headland       Surfing
# 4                                           La Ticla   Free diving
# 5                                 Flat Rock, Ballina  Kite surfing
# 6                              Piedade Beach, Recife      Swimming
# 7  Lighhouse Point Park, Ponce Inlet, Volusia County       Fishing
# 8                       Cocoa Beach, Brevard  County       Walking
# 9                      Daytona Beach, Volusia County      Standing
#
#                      Name Sex   ...         Species   \
# 0             Julie Wolfe    F  ...      White shark
# 1         Adyson McNeely     F  ...              NaN
# 2             John Denges    M  ...              NaN
# 3                    male    M  ...        2 m shark
# 4          Gustavo Ramos     M  ...  Tiger shark, 3m
# 5                 Chris
#     M  ...              NaN
# 6  Jose Ernesto da Silva     M  ...      Tiger shark
# 7                    male    M  ...  Lemon shark, 3'
# 8               Cody High    M  ...   Bull shark, 6'
# 9                    male    M  ...              NaN
#
#              Investigator or Source                            pdf  \
# 0                  R. Collier, GSAF           2018.06.25-Wolfe.pdf
# 1    K.McMurray, TrackingSharks.com         2018.06.18-McNeely.pdf
# 2    K.McMurray, TrackingSharks.com          2018.06.09-Denges.pdf
# 3                    B. Myatt, GSAF       2018.06.08-Arrawarra.pdf
# 4                         A .Kipper           2018.06.04-Ramos.pdf
# 5         Daily Telegraph, 6/4/2018      2018.06.03.b-FlatRock.pdf
# 6    Diario de Pernambuco, 6/4/2018       2018.06.03.a-daSilva.pdf
# 7   K. McMurray, TrackingSharks.com           2018.05.27-Ponce.pdf
# 8    K.McMurray, TrackingSharks.com          2018.05.26.b-High.pdf
# 9  K. McMurray, Tracking Sharks.com  2018.05.26.a-DaytonaBeach.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7  http://sharkattackfile.net/spreadsheets/pdf_di...
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...
# 9  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# 5  http://sharkattackfile.net/spreadsheets/pdf_di...  2018.06.03.b
# 6  http://sharkattackfile.net/spreadsheets/pdf_di...  2018.06.03.a
# 7  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.05.27
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...  2018.05.26.b
# 9  http://sharkattackfile.net/spreadsheets/pdf_di...  2018.05.26.a
#
#   Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0    2018.06.25         6303.0         NaN         NaN
# 1    2018.06.18         6302.0         NaN         NaN
# 2    2018.06.09         6301.0         NaN         NaN
# 3    2018.06.08         6300.0         NaN         NaN
# 4    2018.06.04         6299.0         NaN         NaN
# 5  2018.06.03.b         6298.0         NaN         NaN
# 6  2018.06.03.a         6297.0         NaN         NaN
# 7    2018.05.27         6296.0         NaN         NaN
# 8  2018.05.26.b         6295.0         NaN         NaN
# 9  2018.05.26.a         6294.0         NaN         NaN
#
# [10 rows x 24 columns]

# %% [markdown]
# ### 3º: Start to explore the data from the DataSet.

# %%
data.shape
# Out:
# (25723, 24)

# %%
data.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
data.head(5)
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
#           Species           Investigator or Source                       pdf  \
# 0      White shark                R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1              NaN  K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2              NaN  K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3        2 m shark                  B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4  Tiger shark, 3m                       A .Kipper      2018.06.04-Ramos.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
#
#   Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0    2018.06.25         6303.0         NaN         NaN
# 1    2018.06.18         6302.0         NaN         NaN
# 2    2018.06.09         6301.0         NaN         NaN
# 3    2018.06.08         6300.0         NaN         NaN
# 4    2018.06.04         6299.0         NaN         NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# ### 4º: Start to clean the dataframe to select all data for my hypothesis. I will select the date/year, country,activity and sex.

# %%
data1 = data.loc[:6301]
#Elegido hasta la fila 6301 porque las demás no tienen datos.

# %%
data2 = data1.drop(columns=["Unnamed: 23","Unnamed: 22","href formula"],inplace= False)
#De primeras he elimnado las columnasque no van a ser necesarias para el análisis.

# %%
#A continuación voy a limpiar la columna fecha
date_new = data2["Date"]

# %%
str_date = ",".join(date_new)

# %%
pattern = r'(\d\d-\w+-\d{4}|\w+-\d{4}|\d{4})'
date_search = re.findall(pattern,str_date)

# %%
new_date = pd.Series(date_search)
data2["Date"] = new_date
#Voy a tener que eliminar la siguiente columna porque agrege la fecha en una nueva columna
#y en verdad la quería sustituar por la columna actual. 
data3 = data2.drop(columns="new_dates")

# %%
data3
# Out:
#      Case Number         Date    Year        Type             Country  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating                 USA
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6297     ND.0005  19-Jul-1913     0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004         1911     0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003         1862     0.0  Unprovoked                 USA
# 6300     ND.0002         1906     0.0  Unprovoked              PANAMA
# 6301     ND.0001         1906     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# 0            California          Oceanside, San Diego County      Paddling
# 1               Georgia       St. Simon Island, Glynn County      Standing
# 2                Hawaii                         Habush, Oahu       Surfing
# 3       New South Wales                   Arrawarra Headland       Surfing
# 4                Colima                             La Ticla   Free diving
# ...                 ...                                  ...           ...
# 6297  Western Australia                          Roebuck Bay        Diving
# 6298  Western Australia                                  NaN  Pearl diving
# 6299     North Carolina                       Ocracoke Inlet      Swimming
# 6300                NaN                 Panama Bay 8ºN, 79ºW           NaN
# 6301   Eastern Province  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex   ...  \
# 0               Julie Wolfe    F  ...
# 1           Adyson McNeely     F  ...
# 2               John Denges    M  ...
# 3                      male    M  ...
# 4            Gustavo Ramos     M  ...
# ...                     ...  ...  ...
# 6297                   male    M  ...
# 6298                  Ahmun    M  ...
# 6299  Coast Guard personnel    M  ...
# 6300        Jules Patterson    M  ...
# 6301                   male    M  ...
#
#                                                  Injury Fatal (Y/N)  \
# 0     No injury to occupant, outrigger canoe and pad...           N
# 1                            Minor injury to left thigh           N
# 2          Injury to left lower leg from surfboard skeg           N
# 3                             Minor injury to lower leg           N
# 4     Lacerations to leg & hand shark PROVOKED INCIDENT           N
# ...                                                 ...         ...
# 6297                                              FATAL           Y
# 6298                                              FATAL           Y
# 6299                                              FATAL           Y
# 6300                                              FATAL           Y
# 6301  FATAL. "Shark bit him in half, carrying away t...           Y
#
#                Time         Species                  Investigator or Source  \
# 0             18h00      White shark                       R. Collier, GSAF
# 1     14h00  -15h00              NaN         K.McMurray, TrackingSharks.com
# 2             07h45              NaN         K.McMurray, TrackingSharks.com
# 3               NaN        2 m shark                         B. Myatt, GSAF
# 4               NaN  Tiger shark, 3m                              A .Kipper
# ...             ...              ...                                    ...
# 6297            NaN              NaN       H. Taunton; N. Bartlett,  p. 234
# 6298            NaN              NaN  H. Taunton; N. Bartlett,  pp. 233-234
# 6299            NaN              NaN   F. Schwartz, p.23; C. Creswell, GSAF
# 6300            NaN              NaN                    The Sun, 10/20/1938
# 6301            NaN              NaN                             S.W. Baker
#
#                                  pdf  \
# 0               2018.06.25-Wolfe.pdf
# 1             2018.06.18-McNeely.pdf
# 2              2018.06.09-Denges.pdf
# 3           2018.06.08-Arrawarra.pdf
# 4               2018.06.04-Ramos.pdf
# ...                              ...
# 6297          ND-0005-RoebuckBay.pdf
# 6298               ND-0004-Ahmun.pdf
# 6299  ND-0003-Ocracoke_1900-1905.pdf
# 6300      ND-0002-JulesPatterson.pdf
# 6301              ND-0001-Ceylon.pdf
#
#                                                    href Case Number.1  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                 ...           ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0005
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0004
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0003
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0002
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0001
#
#      Case Number.2 original order
# 0       2018.06.25         6303.0
# 1       2018.06.18         6302.0
# 2       2018.06.09         6301.0
# 3       2018.06.08         6300.0
# 4       2018.06.04         6299.0
# ...            ...            ...
# 6297       ND.0005            6.0
# 6298       ND.0004            5.0
# 6299       ND.0003            4.0
# 6300       ND.0002            3.0
# 6301       ND.0001            2.0
#
# [6302 rows x 21 columns]

# %%
#A continuación voy a filtar el dataframe por la fecha del ataque y el año.
data4 = data3.sort_values("Date")
len(data4)
# Out:
# 6302

# %%
index =range(1,6303)
index
# Out:
# range(1, 6303)

# %%
data4.index = pd.Series(index)
data4
# Out:
#        Case Number         Date    Year          Type     Country  \
# 1       1934.02.22  01-Apr-1934  1934.0    Unprovoked       CHILE
# 2     1934.01.08.R  01-Apr-1934  1934.0       Boating      TURKEY
# 3       1934.02.24  01-Apr-1934  1934.0    Unprovoked   AUSTRALIA
# 4     1960.04.00.c  01-Apr-1960  1960.0    Unprovoked        FIJI
# 5     1972.04.01.a  01-Apr-1972  1972.0    Unprovoked  MOZAMBIQUE
# ...            ...          ...     ...           ...         ...
# 6298    2015.09.00     Sep-2015  2015.0    Unprovoked        FIJI
# 6299    2016.09.00     Sep-2016  2016.0       Invalid      MEXICO
# 6300    2017.09.14     Sep-2017  2017.0       Boating   AUSTRALIA
# 6301  2008.00.00.a  Summer-2008  2008.0    Unprovoked      MEXICO
# 6302    1874.02.15     mid-1870  1874.0  Sea Disaster      TUVALU
#
#                    Area                           Location  \
# 1        Elqui Province                           Coquimbo
# 2              Istanbul         Haydarpasa jetty, Istanbul
# 3         Torres Strait                   Adolphus Channel
# 4            Vanua Levu                  Off the Bua coast
# 5                  Gaza                            Xai Xai
# ...                 ...                                ...
# 6298                NaN                                NaN
# 6299                NaN                   Guadalupe Island
# 6300  Westerm Australia                          Esperance
# 6301    Baja California                  Playas de Tijuana
# 6302                NaN  Between Nanumea & Nanumaga Atolls
#
#                                                Activity  \
# 1                                   Fell into the water
# 2                                               Fishing
# 3                                   Splashing in water
# 4                        Fishing in shoulder-deep water
# 5                                              Swimming
# ...                                                 ...
# 6298                                       Spearfishing
# 6299                                        Cage Diving
# 6300                                            Fishing
# 6301                                            Surfing
# 6302  Fleet of canoes caught by a squall and charged...
#
#                         Name Sex   ...  \
# 1                  a soldier    M  ...
# 2                    2 males    M  ...
# 3       Rixon, an aboriginal    M  ...
# 4               Fijian woman    F  ...
# 5     Richard  George Wilson    M  ...
# ...                      ...  ...  ...
# 6298         Viliame Lautiki    M  ...
# 6299                     NaN  NaN  ...
# 6300                     NaN  NaN  ...
# 6301           Chase Edwards    M  ...
# 6302                     NaN  NaN  ...
#
#                                                  Injury Fatal (Y/N)   Time  \
# 1                                                 FATAL           Y    NaN
# 2                                             No injury           N    NaN
# 3           Lacerated knee & foot, deep puncture wounds           N  12h00
# 4                                   FATAL, legs bitten            Y    NaN
# 5                                                 FATAL           Y  17h00
# ...                                                 ...         ...    ...
# 6298                                         Leg bitten           N    NaN
# 6299     No injury to divers, white shark breached cage         NaN    NaN
# 6300        sharks rammed boats, no injury to occupants           N    NaN
# 6301                                         Leg bitten           N    NaN
# 6302  2 people out of +70 survived, one of whom was ...           Y  Night
#
#                                    Species   \
# 1                                       NaN
# 2                                       NaN
# 3     3.4 m [11']  tiger shark & a 5' shark
# 4                                       NaN
# 5                                       NaN
# ...                                     ...
# 6298                            Tiger shark
# 6299                                Invalid
# 6300                      White shark, 3.5m
# 6301            Possibly a hammerhead shark
# 6302                                    NaN
#
#                                  Investigator or Source  \
# 1                    Los Angeles Times, 2/23/1934, p.20
# 2                                        C. Moore, GSAF
# 3                          V.M. Coppleson (1958), p.243
# 4                    Wellington Evening Post, 4/29/1960
# 5     Note: The Johannesburg Star initially recorded...
# ...                                                 ...
# 6298                               Fiji Times, 2/8/2016
# 6299                                          K. Yonker
# 6300                                     B. Myatt, GSAF
# 6301                         San Diego Reader, 1/7/2009
# 6302                          Otago Witness, 10/28/1897
#
#                                 pdf  \
# 1      1934.02.22-Soldier-Chile.pdf
# 2           1924.02.08.R-Turkey.pdf
# 3              1934.02.24-Rixon.pdf
# 4            1960.04.00.c-woman.pdf
# 5           1972.04.01.a-Wilson.pdf
# ...                             ...
# 6298         2015.09.00-Lautiki.pdf
# 6299          2016.09.00-Breach.pdf
# 6300  2017.09.14-EsperanceBoats.pdf
# 6301       2008.00.00.a-Edwards.pdf
# 6302          1874.02.15-Tuvalu.pdf
#
#                                                    href Case Number.1  \
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...    1934.02.22
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...  1934.02.08.R
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...    1934.02.24
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...  1960.04.00.c
# 5     http://sharkattackfile.net/spreadsheets/pdf_di...  1972.04.01.a
# ...                                                 ...           ...
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...    2015.09.00
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...    2016.09.00
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...    2017.09.14
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...  2008.00.00.a
# 6302  http://sharkattackfile.net/spreadsheets/pdf_di...    1874.02.15
#
#      Case Number.2 original order
# 1       1934.02.22         1355.0
# 2     1934.02.08.R         1354.0
# 3       1934.02.24         1356.0
# 4     1960.04.00.c         2299.0
# 5     1972.04.01.a         2966.0
# ...            ...            ...
# 6298    2015.09.00         5933.0
# 6299    2016.09.00         6077.0
# 6300    2017.09.14         6217.0
# 6301  2008.00.00.a         5004.0
# 6302    1874.02.15          415.0
#
# [6302 rows x 21 columns]

# %%
data4[data4["Year"].isnull()]
# Out:
#        Case Number         Date  Year        Type    Country        Area  \
# 1276  2017.01.08.R  08-Jan-2017   NaN     Invalid  AUSTRALIA  Queensland
# 6019  1836.08.19.R     Dec-1840   NaN  Unprovoked    ENGLAND  Cumberland
#
#         Location      Activity          Name Sex   ...  \
# 1276         NaN  Spearfishing  Kerry Daniel    M  ...
# 6019  Whitehaven      Swimming         a boy    M  ...
#
#                                       Injury Fatal (Y/N) Time    Species   \
# 1276  No attack, shark made a threat display         NaN  NaN  Bull shark
# 6019                                   FATAL           Y  NaN         NaN
#
#       Investigator or Source                           pdf  \
# 1276  Liquid Vision 1/8/2017  2017.01.08.R-KerryDaniel.pdf
# 6019          C. Moore, GSAF   1835.08.19.R-Whitehaven.pdf
#
#                                                    href Case Number.1  \
# 1276  http://sharkattackfile.net/spreadsheets/pdf_di...  2017.01.08.R
# 6019  http://sharkattackfile.net/spreadsheets/pdf_di...  1836.08.19.R
#
#      Case Number.2 original order
# 1276  2017.01.08.R         6116.0
# 6019  1836.08.19.R          224.0
#
# [2 rows x 21 columns]

# %%
data4["Year"][1276] = 2017
# Out:
# <ipython-input-296-281e61e8c5db>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data4["Year"][1276] = 2017

# %%
data4["Year"][6019] = 1840
# Out:
# <ipython-input-298-0aea86e266f7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data4["Year"][6019] = 1840

# %%
data4[data4["Year"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Case Number, Date, Year, Type, Country, Area, Location, Activity, Name, Sex , Age, Injury, Fatal (Y/N), Time, Species , Investigator or Source, pdf, href, Case Number.1, Case Number.2, original order]
# Index: []
#
# [0 rows x 21 columns]

# %%
year = data4["Year"].apply(lambda x: int(x))
data4["Year"] = year
data4["Year"].value_counts()
# Out:
# 2015    143
# 2017    137
# 2016    130
# 2011    128
# 2014    127
#        ...
# 1786      1
# 1758      1
# 1742      1
# 1738      1
# 1554      1
# Name: Year, Length: 249, dtype: int64

# %%
data4.isnull().sum()
# Out:
# Case Number                  1
# Date                         0
# Year                         0
# Type                         4
# Country                     50
# Area                       455
# Location                   540
# Activity                   544
# Name                       210
# Sex                        565
# Age                       2831
# Injury                      28
# Fatal (Y/N)                539
# Time                      3354
# Species                   2838
# Investigator or Source      17
# pdf                          0
# href                         0
# Case Number.1                0
# Case Number.2                0
# original order               0
# dtype: int64

# %%
data6 = data4.drop(columns=["Case Number","Type","Area","Location","Name","Age","Injury","Time","Investigator or Source","pdf","href","Case Number.1","Case Number.2","original order",],inplace= False)
data7 = data6.drop(columns=["Species "],inplace= False)
# Out:
# array(['M', 'F', nan, 'lli', 'M ', '.', 'N'], dtype=object)

# %%
data7
data10 = data7.drop(columns=["Activity"],inplace= False)

# %%
#Clean Columns of Sex
data10["Sex "].unique()
# Out:
# array(['M', 'F', nan, 'lli', 'M ', '.', 'N'], dtype=object)

# %%
data10[data10["Sex "] == "M "] = "M"
data10[data10["Sex "] == "lli"] = "Null"
data10[data10["Sex "] == "."] = "Null"
data10[data10["Sex "] == "N"] = "Null"
data10["Sex "].unique()
# Out:
# array(['M', 'F', nan, 'Null'], dtype=object)

# %%
#Clean Columns of Fatal (Y/N)
data10["Fatal (Y/N)"].unique()
# Out:
# array(['Y', 'N', nan, ' N', 'UNKNOWN', '2017', 'Null', 'M', 'N ', 'y'],
#       dtype=object)

# %%
data10[data10["Fatal (Y/N)"] == " N"] = "N"
data10[data10["Fatal (Y/N)"] == "UNKNOWN"] = "Null"
data10[data10["Fatal (Y/N)"] == "2017"] = "Null"
data10[data10["Fatal (Y/N)"] == "M"] = "N"
data10[data10["Fatal (Y/N)"] == "y"] = "Y"
data10[data10["Fatal (Y/N)"] == "N "] = "N"
data10["Fatal (Y/N)"].unique()
# Out:
# array(['Y', 'N', nan, 'Null'], dtype=object)

# %%
# A continuació elimniaré aquellos datos que están vacíos en sex y fatal.
null_data = data10[data10["Sex "] == data10["Fatal (Y/N)"]]
null_data.index
# Out:
# Int64Index([  34,  143,  145,  146,  342,  571,  591,  639,  743,  826,  866,
#             1003, 1135, 1224, 1366, 1590, 1597, 1652, 1663, 1867, 1877, 2261,
#             2320, 2348, 2365, 2412, 2536, 2626, 2673, 2702, 2716, 2766, 2781,
#             2782, 2878, 2951, 3004, 3006, 3008, 3009, 3023, 3051, 3129, 3165,
#             3178, 3430, 3563, 3566, 3639, 3673, 3681, 3768, 3802, 3821, 3836,
#             3868, 3925, 4082, 4154, 4225, 4291, 4306, 4347, 4374, 4412, 4575,
#             4673, 4960, 4993, 5033, 5105, 5110, 5128, 5150, 5186, 5197, 5320,
#             5329, 5455, 5549, 5560, 5581, 5694, 5952, 6035, 6078, 6223, 6287],
#            dtype='int64')

# %%
data11 = data10.drop(axis=0,index=null_data.index)

# %%
data11.dropna(axis=0, subset=['Sex ','Fatal (Y/N)'],inplace= True)

# %%
data11.value_counts(subset=["Date"])
# Out:
# Date
# 1950           15
# 1960           12
# 1958           11
# 1957           11
# 1942            9
#                ..
# 12-Nov-2013     1
# 12-Oct-1921     1
# 12-Oct-1927     1
# 12-Oct-1942     1
# Summer-2008     1
# Length: 4409, dtype: int64

# %%
len(data11)
# Out:
# 5220

# %%
index2 = range(1,5221)
data11.index = index2
data_clear = data11.rename(columns={"Sex ":"Sex","Fatal (Y/N)":"Fatal"})
len(data_clear)
# Out:
# 5220

# %%
#A contuniación voy a limpiar por mes y año.
moth_year = data_clear["Date"]
str_moth_year = ",".join(moth_year)
pattern = r'(\w+-\d{4}|\d{4})'
str_moth_year_search = re.findall(pattern,str_moth_year)
len(str_moth_year_search)
new_moth_year = pd.Series(str_moth_year_search)
data_clear["Date"] = new_moth_year
new_moth_year
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-526-1b091db142c3> in <module>
#       1 #A contuniación voy a limpiar por mes y año.
#       2 moth_year = data_clear["Date"]
# ----> 3 str_moth_year = ",".join(moth_year)
#       4 pattern = r'(\w+-\d{4}|\d{4})'
#       5 str_moth_year_search = re.findall(pattern,str_moth_year)
#
# TypeError: sequence item 5219: expected str instance, float found

# %%
data_clear["Date"][5220] = "2018"
data_clear["Date"][5220]
# Out:
# '2018'

# %%
moth_date = data_clear["Date"]
list_moth_str = ",".join(moth_date)
len(list_moth_str)
pattern = r'(\D+)'
str_moth_search = re.findall(pattern,list_moth_str)
len(str_moth_search)
# Out:
# 5237

# %%
mon_search = pd.Series(str_moth_search)
data_clear["Date"] = mon_search
# Out:
#     Date  Year     Country Sex Fatal
# 1  ,Apr-  1934       CHILE   M     Y
# 2  ,Apr-  1934      TURKEY   M     N
# 3  ,Apr-  1934   AUSTRALIA   M     N
# 4  ,Apr-  1960        FIJI   F     Y
# 5  ,Apr-  1972  MOZAMBIQUE   M     Y

# %%
df= data_clear.rename(columns={"Date":"Moth"})

# %%
data_clear1 = data_clear.rename(columns={"Date":"Moth"})

# %% [markdown]
# ### limpiar los años

# %%
data_clear1.head(5)
# Out:
#     Moth  Year     Country Sex Fatal
# 1  ,Apr-  1934       CHILE   M     Y
# 2  ,Apr-  1934      TURKEY   M     N
# 3  ,Apr-  1934   AUSTRALIA   M     N
# 4  ,Apr-  1960        FIJI   F     Y
# 5  ,Apr-  1972  MOZAMBIQUE   M     Y

# %%
no_year = data_clear1[data_clear1["Year"] == 0]
no_year.index
# Out:
# Int64Index([1083, 2219, 2220, 2221, 2222, 2371, 2372, 2373, 2374, 2375,
#             ...
#             4947, 4989, 4990, 5031, 5045, 5135, 5146, 5153, 5154, 5200],
#            dtype='int64', length=115)

# %%
data_clear1.drop(axis=0, index=no_year.index, inplace= True )
data_clear1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-593-dfbd3660fb9e> in <module>
# ----> 1 data_clear1.drop(axis=0, index=no_year.index, inplace= True )
#       2 data_clear1
#
# /usr/local/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4303                 weight  1.0     0.8
#    4304         """
# -> 4305         return super().drop(
#    4306             labels=labels,
#    4307             axis=axis,
#
# /usr/local/lib/python3.9/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4150         for axis, labels in axes.items():
#    4151             if labels is not None:
# -> 4152                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4153
#    4154         if inplace:
#
# /usr/local/lib/python3.9/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4185                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4186             else:
# -> 4187                 new_axis = axis.drop(labels, errors=errors)
#    4188             result = self.reindex(**{axis_name: new_axis})
#    4189
#
# /usr/local/lib/python3.9/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: '[1083 2219 2220 2221 2222 2371 2372 2373 2374 2375 2427 2499 2502 2672\n 2689 2698 2793 2794 2813 2867 2870 2872 2873 2881 2882 2883 2885 2888\n 2890 2894 2895 2896 2901 2902 2904 2908 2912 2913 2914 2916 2923 2927\n 2935 2941 2942 2943 2944 2951 2957 2958 2960 2962 2970 2971 2972 2973\n 2974 2990 2995 3020 3021 3023 3028 3048 3049 3060 3062 3066 3067 3068\n 3069 3074 3084 3085 3086 3088 3089 3094 3098 3100 3101 3102 3103 3104\n 3106 3108 3118 3134 3135 3162 3163 3172 3179 3310 3311 3312 3314 3318\n 3319 3321 3322 3325 3326 3328 3333 4947 4989 4990 5031 5045 5135 5146\n 5153 5154 5200] not found in axis'

# %%
data_clear1.sort_values(by="Year")
# Out:
#        Moth  Year                   Country Sex Fatal
# 2487      ,  1543                 VENEZUELA   M     Y
# 720   ,Apr-  1580  Between PORTUGAL & INDIA   M     Y
# 2488      ,  1642                       USA   M     Y
# 2490      ,  1700                    FRANCE   M     N
# 2491      ,  1700                    FRANCE   M     Y
# ...     ...   ...                       ...  ..   ...
# 1856  ,Nov-  2018                       USA   M     N
# 1855  ,May-  2018                   ENGLAND   M     N
# 4603  ,Sep-  2018                  THAILAND   M     N
# 4802  ,Jul-  2018                       USA   M     N
# 2105  ,Jan-  2018                 AUSTRALIA   M     N
#
# [5067 rows x 5 columns]

# %%
data_clear1.drop(axis=0, index=2498, inplace=True)
data_clear1.drop(axis=0, index=2500, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-599-1fc566ef8ac9> in <module>
# ----> 1 data_clear1.drop(axis=0, index=2498, inplace=True)
#       2 data_clear1.drop(axis=0, index=2500, inplace=True)
#       3 data_clear1
#
# /usr/local/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4303                 weight  1.0     0.8
#    4304         """
# -> 4305         return super().drop(
#    4306             labels=labels,
#    4307             axis=axis,
#
# /usr/local/lib/python3.9/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4150         for axis, labels in axes.items():
#    4151             if labels is not None:
# -> 4152                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4153
#    4154         if inplace:
#
# /usr/local/lib/python3.9/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4185                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4186             else:
# -> 4187                 new_axis = axis.drop(labels, errors=errors)
#    4188             result = self.reindex(**{axis_name: new_axis})
#    4189
#
# /usr/local/lib/python3.9/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: '[2498] not found in axis'

# %%
data_clear1
data_clear1.index = range(1,5104)
data_clear1.sort_values(by="Year")
data_clear1.drop(axis=0, index=4095, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-605-ce4f6afac39a> in <module>
#       1 data_clear1
# ----> 2 data_clear1.index = range(1,5104)
#       3 data_clear1.sort_values(by="Year")
#       4 data_clear1.drop(axis=0, index=4095, inplace=True)
#       5 data_clear1
#
# /usr/local/lib/python3.9/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5473         try:
#    5474             object.__getattribute__(self, name)
# -> 5475             return object.__setattr__(self, name, value)
#    5476         except AttributeError:
#    5477             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# /usr/local/lib/python3.9/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     667     def _set_axis(self, axis: int, labels: Index) -> None:
#     668         labels = ensure_index(labels)
# --> 669         self._mgr.set_axis(axis, labels)
#     670         self._clear_item_cache()
#     671
#
# /usr/local/lib/python3.9/site-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     218
#     219         if new_len != old_len:
# --> 220             raise ValueError(
#     221                 f"Length mismatch: Expected axis has {old_len} elements, new "
#     222                 f"values have {new_len} elements"
#
# ValueError: Length mismatch: Expected axis has 5102 elements, new values have 5103 elements

# %%
data_clear1.dropna(axis=0,subset="Country")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-631-105761ebff05> in <module>
# ----> 1 data_clear1.dropna(axis=0,subset="Country")
#
# /usr/local/lib/python3.9/site-packages/pandas/core/frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    5154         if subset is not None:
#    5155             ax = self._get_axis(agg_axis)
# -> 5156             indices = ax.get_indexer_for(subset)
#    5157             check = indices == -1
#    5158             if check.any():
#
# /usr/local/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_indexer_for(self, target, **kwargs)
#    4958         """
#    4959         if self._index_as_unique:
# -> 4960             return self.get_indexer(target, **kwargs)
#    4961         indexer, _ = self.get_indexer_non_unique(target)
#    4962         return indexer
#
# /usr/local/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_indexer(self, target, method, limit, tolerance)
#    3145     ) -> np.ndarray:
#    3146         method = missing.clean_reindex_fill_method(method)
# -> 3147         target = ensure_index(target)
#    3148         if tolerance is not None:
#    3149             tolerance = self._convert_tolerance(tolerance, target)
#
# /usr/local/lib/python3.9/site-packages/pandas/core/indexes/base.py in ensure_index(index_like, copy)
#    5915             index_like = copy_func(index_like)
#    5916
# -> 5917     return Index(index_like)
#    5918
#    5919
#
# /usr/local/lib/python3.9/site-packages/pandas/core/indexes/base.py in __new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     370
#     371         elif data is None or is_scalar(data):
# --> 372             raise cls._scalar_data_error(data)
#     373         elif hasattr(data, "__array__"):
#     374             return Index(np.asarray(data), dtype=dtype, copy=copy, name=name, **kwargs)
#
# TypeError: Index(...) must be called with a collection of some kind, 'Country' was passed

# %%
data_clear1.drop(data_clear1[data_clear1["Country"].isnull()].index,inplace=True)

# %%
data_clear2 = data_clear1.sort_values(by="Year", ascending=False)
data_clear3 = data_clear2[:1157]
len(data_clear3)
# Out:
# 1157

# %%
data_clear6 = data_clear3.drop_duplicates()
len(data_clear6)
data_clear6.index = range(0,679)
data_clear6
# Out:
#       Moth  Year       Country Sex Fatal
# 0    ,Jul-  2018     AUSTRALIA   M     N
# 1    ,Nov-  2018           USA   M     N
# 2    ,May-  2018     AUSTRALIA   M     N
# 3    ,Feb-  2018     AUSTRALIA   M     N
# 4    ,Sep-  2018      THAILAND   M     N
# ..     ...   ...           ...  ..   ...
# 674  ,Oct-  2008           USA   M     N
# 675  ,Dec-  2008  SOUTH AFRICA   M     N
# 676  ,Feb-  2008     AUSTRALIA   F     N
# 677  ,May-  2008           USA   M     N
# 678  ,Jul-  2008        PANAMA   M     N
#
# [679 rows x 5 columns]

# %% [markdown]
# ### 6º: Export the dataframe

# %%
data_clear6.to_csv("data_clean.csv",index=False)

# %% [markdown]
# ### In this explaration I observed:
# - That the column of "Case Number" is wrong because are dates and no numbers. And I need to replace with the column of "original order".
# - From row x there is no type of data. Therefore they should be removed.
# - The columns "href formula" and "href" are the same. So i choice one of them.
# - The columns "Case Number.1" and "Case Number.2" are wrong. It´s the same that happend to the column of "Case Number".
# - And the columns "Unnamed: 22" and "Unnamed: 23" are empty.
